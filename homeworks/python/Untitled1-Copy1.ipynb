# %%
import pandas as pd

# %%
bookings = pd.read_csv('/mnt/HC_Volume_18315164/home-jupyter/jupyter-s-belihin-38/shared/homeworks/python_ds_miniprojects/2/bookings.csv', sep=';')

# %%
bookings.shape
# Out:
# (119390, 21)

# %%
shapex = bookings.shape

# %%
shapex[0]
# Out:
# 119390

# %%
shapex[1]
# Out:
# 21

# %%
df_shape = 'df has {} rows and {} columns'

# %%
df_shape = df_shape.format(shapex[0],shapex[1])

# %%
df_shape
# Out:
# 'df has 119390 rows and 21 columns'

# %%
df = bookings

# %%
df.isna().sum()
# Out:
# hotel                          0
# is_canceled                    0
# lead_time                      0
# arrival_full_date              0
# arrival_date_year              0
# arrival_date_month             0
# arrival_date_week_number       0
# arrival_date_day_of_month      0
# stays_in_weekend_nights        0
# stays_in_week_nights           0
# stays_total_nights             0
# adults                         0
# children                       4
# babies                         0
# meal                           0
# country                      488
# reserved_room_type             0
# assigned_room_type             0
# customer_type                  0
# reservation_status             0
# reservation_status_date        0
# total_kids                     4
# has_kids                       0
# older_than_30                  0
# dtype: int64

# %%
df.astype({'children':'int64'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-dbaeeb0b171f> in <module>
# ----> 1 df.astype({'children':'int64'})
#
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5526                 if col_name in dtype:
#    5527                     results.append(
# -> 5528                         col.astype(dtype=dtype[col_name], copy=copy, errors=errors)
#    5529                     )
#    5530                 else:
#
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5541         else:
#    5542             # else, only a single dtype is given
# -> 5543             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5544             return self._constructor(new_data).__finalize__(self, method="astype")
#    5545
#
# ...

# %%
bookings.dtypes
# Out:
# Hotel                         object
# Is Canceled                    int64
# Lead Time                      int64
# arrival full date             object
# Arrival Date Year              int64
# Arrival Date Month            object
# Arrival Date Week Number       int64
# Arrival Date Day of Month      int64
# Stays in Weekend nights        int64
# Stays in week nights           int64
# stays total nights             int64
# Adults                         int64
# Children                     float64
# Babies                         int64
# Meal                          object
# Country                       object
# Reserved Room Type            object
# Assigned room type            object
# customer type                 object
# Reservation Status            object
# Reservation status_date       object
# dtype: object

# %%
bookings_head = bookings[:7]

# %%
bookings_head
# Out:
#           Hotel  Is Canceled  Lead Time arrival full date  Arrival Date Year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
# 5  Resort Hotel            0         14        2015-07-01               2015
# 6  Resort Hotel            0          0        2015-07-01               2015
#
#   Arrival Date Month  Arrival Date Week Number  Arrival Date Day of Month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# ...

# %%
bookings.columns.str.lower().str.replace(' ', '_')
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_full_date',
#        'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'stays_total_nights', 'adults', 'children',
#        'babies', 'meal', 'country', 'reserved_room_type', 'assigned_room_type',
#        'customer_type', 'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
bookings.columns = bookings.columns.str.lower().str.replace(' ', '_')

# %%
bookings
# Out:
#                hotel  is_canceled  lead_time arrival_full_date  \
# 0       Resort Hotel            0        342        2015-07-01
# 1       Resort Hotel            0        737        2015-07-01
# 2       Resort Hotel            0          7        2015-07-01
# 3       Resort Hotel            0         13        2015-07-01
# 4       Resort Hotel            0         14        2015-07-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-08-30
# 119386    City Hotel            0        102        2017-08-31
# 119387    City Hotel            0         34        2017-08-31
# 119388    City Hotel            0        109        2017-08-31
# 119389    City Hotel            0        205        2017-08-29
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 0                    2015               July                        27
# ...

# %%
bookings.query('is_canceled == 0').groupby(['country']).agg({'country':'count'}).nlargest(5,'country')
# Out:
#          country
# country
# PRT        21071
# GBR         9676
# FRA         8481
# ESP         6391
# DEU         6069

# %%
bookings.groupby(['hotel']).agg({'stays_total_nights':'mean'}).round(2)
# Out:
#               stays_total_nights
# hotel
# City Hotel                  2.98
# Resort Hotel                4.32

# %%
bookings.query('reserved_room_type != assigned_room_type').shape
# Out:
# (14917, 21)

# %%
bookings.groupby('arrival_date_year')['arrival_date_month'].max()
# Out:
# arrival_date_year
# 2015    September
# 2016    September
# 2017          May
# Name: arrival_date_month, dtype: object

# %%
bookings.query('is_canceled == 1').groupby(['arrival_date_year', 'arrival_date_month', 'hotel']).agg({'arrival_date_month':'count'})
# Out:
#                                                    arrival_date_month
# arrival_date_year arrival_date_month hotel
# 2015              August             City Hotel                  1232
#                                      Resort Hotel                 366
#                   December           City Hotel                   668
#                                      Resort Hotel                 305
#                   July               City Hotel                   939
#                                      Resort Hotel                 320
#                   November           City Hotel                   301
#                                      Resort Hotel                 185
#                   October            City Hotel                  1321
#                                      Resort Hotel                 411
#                   September          City Hotel                  1543
#                                      Resort Hotel                 551
# ...

# %%
bookings.query('is_canceled == 1').groupby(['arrival_date_year', 'arrival_date_month', 'hotel']).agg({'arrival_date_month':'count'}).groupby(['arrival_date_year']).idxmax()
# Out:
#                               arrival_date_month
# arrival_date_year
# 2015               (2015, September, City Hotel)
# 2016                 (2016, October, City Hotel)
# 2017                     (2017, May, City Hotel)

# %%
k = bookings.query('is_canceled == 1' and 'hotel == "City Hotel"').groupby(['arrival_date_year', 'arrival_date_month'])

# %%
k['hotel'].value_counts()
# Out:
# arrival_date_year  arrival_date_month  hotel
# 2015               August              City Hotel    2480
#                    December            City Hotel    1654
#                    July                City Hotel    1398
#                    November            City Hotel    1235
#                    October             City Hotel    3386
#                    September           City Hotel    3529
# 2016               April               City Hotel    3561
#                    August              City Hotel    3378
#                    December            City Hotel    2478
#                    February            City Hotel    2371
#                    January             City Hotel    1364
#                    July                City Hotel    3131
#                    June                City Hotel    3923
#                    March               City Hotel    3046
#                    May                 City Hotel    3676
# ...

# %%
bookings.agg({'adults':'mean', 'children':'mean','babies':'mean'})
# Out:
# adults      1.856403
# children    0.103890
# babies      0.007949
# dtype: float64

# %%
bookings['total_kids'] = bookings['children'] + bookings['babies']

# %%
bookings.groupby(['hotel']).agg({'total_kids':'mean'}).round(2)
# Out:
#               total_kids
# hotel
# City Hotel          0.10
# Resort Hotel        0.14

# %%
bookings.query('total_kids > 0').count()
# Out:
# hotel                        9332
# is_canceled                  9332
# lead_time                    9332
# arrival_full_date            9332
# arrival_date_year            9332
# arrival_date_month           9332
# arrival_date_week_number     9332
# arrival_date_day_of_month    9332
# stays_in_weekend_nights      9332
# stays_in_week_nights         9332
# stays_total_nights           9332
# adults                       9332
# children                     9332
# babies                       9332
# meal                         9332
# country                      9318
# reserved_room_type           9332
# assigned_room_type           9332
# customer_type                9332
# reservation_status           9332
# reservation_status_date      9332
# total_kids                   9332
# dtype: int64

# %%
bookings.query('total_kids > 0 and is_canceled == 1').count()
# Out:
# hotel                        3259
# is_canceled                  3259
# lead_time                    3259
# arrival_full_date            3259
# arrival_date_year            3259
# arrival_date_month           3259
# arrival_date_week_number     3259
# arrival_date_day_of_month    3259
# stays_in_weekend_nights      3259
# stays_in_week_nights         3259
# stays_total_nights           3259
# adults                       3259
# children                     3259
# babies                       3259
# meal                         3259
# country                      3259
# reserved_room_type           3259
# assigned_room_type           3259
# customer_type                3259
# reservation_status           3259
# reservation_status_date      3259
# total_kids                   3259
# dtype: int64

# %%
l = bookings.query('total_kids > 0 and is_canceled == 1').count() / bookings.query('total_kids > 0').count()

# %%
l=l*100

# %%
l.round(2)
# Out:
# hotel                        34.92
# is_canceled                  34.92
# lead_time                    34.92
# arrival_full_date            34.92
# arrival_date_year            34.92
# arrival_date_month           34.92
# arrival_date_week_number     34.92
# arrival_date_day_of_month    34.92
# stays_in_weekend_nights      34.92
# stays_in_week_nights         34.92
# stays_total_nights           34.92
# adults                       34.92
# children                     34.92
# babies                       34.92
# meal                         34.92
# country                      34.98
# reserved_room_type           34.92
# assigned_room_type           34.92
# customer_type                34.92
# reservation_status           34.92
# reservation_status_date      34.92
# total_kids                   34.92
# dtype: float64

# %%
bookings['has_kids'] = 0

# %%
bookings['has_kids'] = bookings.has_kids != bookings.total_kids

# %%
bookings.query('has_kids == True')
# Out:
#                hotel  is_canceled  lead_time arrival_full_date  \
# 13      Resort Hotel            0         18        2015-07-01
# 45      Resort Hotel            1         47        2015-07-02
# 55      Resort Hotel            0          1        2015-07-02
# 65      Resort Hotel            0         10        2015-07-03
# 87      Resort Hotel            1         79        2015-07-03
# ...              ...          ...        ...               ...
# 119270    City Hotel            0          0        2017-08-29
# 119287    City Hotel            0        167        2017-08-27
# 119293    City Hotel            0        243        2017-08-30
# 119318    City Hotel            0        160        2017-08-29
# 119319    City Hotel            0         45        2017-08-28
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 13                   2015               July                        27
# ...

# %%
bookings.lead_time.head
# Out:
# <bound method NDFrame.head of 0         342
# 1         737
# 2           7
# 3          13
# 4          14
#          ...
# 119385     23
# 119386    102
# 119387     34
# 119388    109
# 119389    205
# Name: lead_time, Length: 119390, dtype: int64>

# %%
bookings['older_than_30'] = 30 > bookings.lead_time

# %%
bookings['older_than_30']
# Out:
# 0         False
# 1         False
# 2          True
# 3          True
# 4          True
#           ...
# 119385     True
# 119386    False
# 119387    False
# 119388    False
# 119389    False
# Name: older_than_30, Length: 119390, dtype: bool

# %%
k=bookings.query('has_kids == True and is_canceled == 1').count() / bookings.query('has_kids == True').count()

# %%
bookings.query('has_kids == True and is_canceled == 1').count()
# Out:
# hotel                        3263
# is_canceled                  3263
# lead_time                    3263
# arrival_full_date            3263
# arrival_date_year            3263
# arrival_date_month           3263
# arrival_date_week_number     3263
# arrival_date_day_of_month    3263
# stays_in_weekend_nights      3263
# stays_in_week_nights         3263
# stays_total_nights           3263
# adults                       3263
# children                     3259
# babies                       3263
# meal                         3263
# country                      3263
# reserved_room_type           3263
# assigned_room_type           3263
# customer_type                3263
# reservation_status           3263
# reservation_status_date      3263
# total_kids                   3259
# has_kids                     3263
# older_than_30                3263
# dtype: int64

# %%
bookings.query('has_kids == True').count()
# Out:
# hotel                        9336
# is_canceled                  9336
# lead_time                    9336
# arrival_full_date            9336
# arrival_date_year            9336
# arrival_date_month           9336
# arrival_date_week_number     9336
# arrival_date_day_of_month    9336
# stays_in_weekend_nights      9336
# stays_in_week_nights         9336
# stays_total_nights           9336
# adults                       9336
# children                     9332
# babies                       9336
# meal                         9336
# country                      9322
# reserved_room_type           9336
# assigned_room_type           9336
# customer_type                9336
# reservation_status           9336
# reservation_status_date      9336
# total_kids                   9332
# has_kids                     9336
# older_than_30                9336
# dtype: int64

# %%
k=k*100

# %%
k.round(2)
# Out:
# hotel                        34.95
# is_canceled                  34.95
# lead_time                    34.95
# arrival_full_date            34.95
# arrival_date_year            34.95
# arrival_date_month           34.95
# arrival_date_week_number     34.95
# arrival_date_day_of_month    34.95
# stays_in_weekend_nights      34.95
# stays_in_week_nights         34.95
# stays_total_nights           34.95
# adults                       34.95
# children                     34.92
# babies                       34.95
# meal                         34.95
# country                      35.00
# reserved_room_type           34.95
# assigned_room_type           34.95
# customer_type                34.95
# reservation_status           34.95
# reservation_status_date      34.95
# total_kids                   34.92
# has_kids                     34.95
# older_than_30                34.95
# dtype: float64

# %%
bookings.query('total_kids > 1').groupby(['arrival_date_year', 'arrival_date_month'])

# %%
q = bookings.query('total_kids == 0 and is_canceled == 1').count() / bookings.query('total_kids == 0').count()

# %%
q=q*100

# %%
q.round(2)
# Out:
# hotel                        37.22
# is_canceled                  37.22
# lead_time                    37.22
# arrival_full_date            37.22
# arrival_date_year            37.22
# arrival_date_month           37.22
# arrival_date_week_number     37.22
# arrival_date_day_of_month    37.22
# stays_in_weekend_nights      37.22
# stays_in_week_nights         37.22
# stays_total_nights           37.22
# adults                       37.22
# children                     37.22
# babies                       37.22
# meal                         37.22
# country                      37.32
# reserved_room_type           37.22
# assigned_room_type           37.22
# customer_type                37.22
# reservation_status           37.22
# reservation_status_date      37.22
# total_kids                   37.22
# has_kids                     37.22
# older_than_30                37.22
# dtype: float64
