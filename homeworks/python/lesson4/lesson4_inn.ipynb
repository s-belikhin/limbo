# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
import os

# %matplotlib inline

# %%
os.listdir('/mnt/HC_Volume_18315164/home-jupyter/jupyter-s-belihin-38/shared/homeworks/python_ds_miniprojects/4_inn')
# Out:
# ['inn.xls', 'necessary_inn.txt']

# %%
df_xls = pd.read_excel('/mnt/HC_Volume_18315164/home-jupyter/jupyter-s-belihin-38/shared/homeworks/python_ds_miniprojects/4_inn/inn.xls')

# %%
df_xls.head()
# Out:
#    Unnamed: 0  #                                    name     reg_number  \
# 0           0  0         ЗАО «Власова, Макаров и Шашков»  1143692580560
# 1           1  1  РАО «Тимофеева, Алексеева и Кузнецова»  9342309660697
# 2           2  2                      РАО «Юдин-Ефимова»  1277485323451
# 3           3  3                   Доронин Инкорпорэйтед  7139161431511
# 4           4  4    Объединенная энергетическая компания  6114798049639
#
#                                              address  \
# 0  д. Кирово-Чепецк, пр. Металлургов, д. 537 к. 3...
# 1  г. Арзамас, наб. Фестивальная, д. 7 стр. 8/2, ...
# 2  п. Меренга, алл. Достоевского, д. 3/4 к. 497, ...
# 3  д. Иваново, ул. Красных Партизан, д. 83 к. 4, ...
# 4           к. Энгельс, наб. Шишкина, д. 120, 823828
#
#                           head              head_job      head_inn  \
# 0        Жданов Карл Виленович              Маммолог  109092209811
# 1  Рожков Харлампий Алексеевич           Воспитатель  704229465069
# ...

# %%
df_xls.dtypes
# Out:
# Unnamed: 0                 int64
# #                          int64
# name                      object
# reg_number                 int64
# address                   object
# head                      object
# head_job                  object
# head_inn                   int64
# phone                     object
# email                     object
# site                      object
# registration_date         object
# nalogoplatelschik_code    object
# oktmo_code                 int64
# okato_code                 int64
# registration_region       object
# okato_name                object
# field                     object
# capital,RUB                int64
# income,RUB                 int64
# dtype: object

# %%
df_txt = pd.read_csv('/mnt/HC_Volume_18315164/home-jupyter/jupyter-s-belihin-38/shared/homeworks/python_ds_miniprojects/4_inn/necessary_inn.txt', header = None)

# %%
df_txt
# Out:
#                 0
# 0    394609645484
# 1    281578625230
# 2    923769811917
# 3    998694734508
# 4    271011690615
# ..            ...
# 110  664306216794
# 111  991951385204
# 112  129413497752
# 113  447901012904
# 114  634037614688
#
# [115 rows x 1 columns]

# %%
df_txt.dtypes
# Out:
# 0    int64
# dtype: object

# %%
df_txt = df_txt.rename(columns={df_txt.columns[0]: 'head_inn'}) # присваиваем имя колонке без названия

# %%
df_txt
# Out:
#          head_inn
# 0    394609645484
# 1    281578625230
# 2    923769811917
# 3    998694734508
# 4    271011690615
# ..            ...
# 110  664306216794
# 111  991951385204
# 112  129413497752
# 113  447901012904
# 114  634037614688
#
# [115 rows x 1 columns]

# %%
merge_df = df_txt.merge(df_xls, how='inner', on = 'head_inn')

# %%
merge_df
# Out:
#          head_inn  Unnamed: 0     #                          name  \
# 0    394609645484         191   191       АО «Колесников Чернова»
# 1    281578625230         300   300                 Татэнергосбыт
# 2    923769811917        1509  1509               НПО «Стрелкова»
# 3    998694734508        2021  2021           ЗАО «Крылова Юдина»
# 4    271011690615        1186  1186         Тетра Пак (Tetra Pak)
# ..            ...         ...   ...                           ...
# 110  664306216794        1218  1218                 Деловые линии
# 111  991951385204         493   493  Вольво Карс (Zhejiang Geely)
# 112  129413497752        1901  1901                    Крюков Лтд
# 113  447901012904         775   775       ЗАО «Тихонова Абрамова»
# 114  634037614688        1790  1790                  Белякова Лтд
#
#         reg_number                                            address  \
# 0    9272097078860       д. Чегем, бул. Фрунзе, д. 4 стр. 480, 072269
# ...

# %%
merge_df['income,RUB'].sum()
# Out:
# 6104522627393
