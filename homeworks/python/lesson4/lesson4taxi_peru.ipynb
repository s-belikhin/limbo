# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

# %matplotlib inline

# %%
taxi = pd.read_csv('/mnt/HC_Volume_18315164/home-jupyter/jupyter-s-belihin-38/homeworks/lesson4/3_taxi_peru.csv', sep=';')

# %%
taxi
# Out:
#                              journey_id                           user_id  \
# 0      23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 1      dd2af4715d0dc16eded53afc0e243577  a553c46e3a22fb9c326aeb3d72b3334e
# 2      dd91e131888064bf7df3ce08f3d4b4ad  a553c46e3a22fb9c326aeb3d72b3334e
# 3      dd2af4715d0dc16eded53afc0e2466d0  a553c46e3a22fb9c326aeb3d72b3334e
# 4      85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
# ...                                 ...                               ...
# 23106  4a18ea5737ce0ffecaf20b305a0e2c86  8998bb370b5f0cec43a373adebba0c72
# 23107  f1e4317f2c17991dd90d1cd17ae0d399  5f8a6ffef0ea5df78a8ee890267b60ec
# 23108  1e44c0fd0a266c3719ff30410b257bce  c0ffb6f6cd801004dd8609c12277c2d1
# 23109  7073883383b89ad289e864022150cdd7  c0ffb6f6cd801004dd8609c12277c2d1
# 23110  b7dea45c3cc92b9efd5a4905e69ff9bf  c0ffb6f6cd801004dd8609c12277c2d1
#
#                               driver_id                           taxi_id  \
# ...

# %%
taxi['start_at'] = pd.to_datetime(taxi.start_at, dayfirst = True)
taxi['end_at'] = pd.to_datetime(taxi.end_at, dayfirst = True)
taxi['arrived_at'] = pd.to_datetime(taxi.arrived_at, dayfirst = True)

# %%
taxi = taxi.query('start_type == "asap" or start_type == "reserved"')

# %%
taxi.shape
# Out:
# (23091, 20)

# %%
taxi1=taxi

# %%
taxi1['wait_time'] = taxi1['arrived_at'] - taxi1['start_at']

# %%
taxi1.head()
# Out:
#                          journey_id                           user_id  \
# 0  23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 1  dd2af4715d0dc16eded53afc0e243577  a553c46e3a22fb9c326aeb3d72b3334e
# 2  dd91e131888064bf7df3ce08f3d4b4ad  a553c46e3a22fb9c326aeb3d72b3334e
# 3  dd2af4715d0dc16eded53afc0e2466d0  a553c46e3a22fb9c326aeb3d72b3334e
# 4  85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
#
#                           driver_id                           taxi_id  \
# 0  583949a89a9ee17d19e3ca4f137b6b4c  b12f4f09c783e29fe0d0ea624530db56
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4  d665fb9f75ef5d9cd0fd89479380ba78  0accdd3aa5a322f4129fa20b53278c69
#
#         icon start_type            start_at     start_lat     start_lon  \
# ...

# %%
taxi1.dtypes
# Out:
# journey_id                   object
# user_id                      object
# driver_id                    object
# taxi_id                      object
# icon                         object
# start_type                   object
# start_at             datetime64[ns]
# start_lat                    object
# start_lon                    object
# end_at               datetime64[ns]
# end_lat                      object
# end_lon                      object
# end_state                    object
# driver_start_lat             object
# driver_start_lon             object
# arrived_at           datetime64[ns]
# source                       object
# driver_score                float64
# rider_score                 float64
# wait_time           timedelta64[ns]
# dtype: object

# %%
taxi1.wait_time.astype('timedelta64[m]')
# Out:
# 0        18.0
# 1         NaN
# 2         NaN
# 3         NaN
# 4        -5.0
#          ...
# 23106     0.0
# 23107    13.0
# 23108     9.0
# 23109    -7.0
# 23110     NaN
# Name: wait_time, Length: 23091, dtype: float64

# %%
taxi1.dtypes
# Out:
# journey_id                   object
# user_id                      object
# driver_id                    object
# taxi_id                      object
# icon                         object
# start_type                   object
# start_at             datetime64[ns]
# start_lat                    object
# start_lon                    object
# end_at               datetime64[ns]
# end_lat                      object
# end_lon                      object
# end_state                    object
# driver_start_lat             object
# driver_start_lon             object
# arrived_at           datetime64[ns]
# source                       object
# driver_score                float64
# rider_score                 float64
# wait_time           timedelta64[ns]
# dtype: object

# %%
taxi1
# Out:
#                              journey_id                           user_id  \
# 0      23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 1      dd2af4715d0dc16eded53afc0e243577  a553c46e3a22fb9c326aeb3d72b3334e
# 2      dd91e131888064bf7df3ce08f3d4b4ad  a553c46e3a22fb9c326aeb3d72b3334e
# 3      dd2af4715d0dc16eded53afc0e2466d0  a553c46e3a22fb9c326aeb3d72b3334e
# 4      85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
# ...                                 ...                               ...
# 23106  4a18ea5737ce0ffecaf20b305a0e2c86  8998bb370b5f0cec43a373adebba0c72
# 23107  f1e4317f2c17991dd90d1cd17ae0d399  5f8a6ffef0ea5df78a8ee890267b60ec
# 23108  1e44c0fd0a266c3719ff30410b257bce  c0ffb6f6cd801004dd8609c12277c2d1
# 23109  7073883383b89ad289e864022150cdd7  c0ffb6f6cd801004dd8609c12277c2d1
# 23110  b7dea45c3cc92b9efd5a4905e69ff9bf  c0ffb6f6cd801004dd8609c12277c2d1
#
#                               driver_id                           taxi_id  \
# ...

# %%
taxi1.wait_time = taxi1.wait_time.astype('timedelta64[m]')

# %%
taxi1.wait_time
# Out:
# 0        18.0
# 1         NaN
# 2         NaN
# 3         NaN
# 4        -5.0
#          ...
# 23106     0.0
# 23107    13.0
# 23108     9.0
# 23109    -7.0
# 23110     NaN
# Name: wait_time, Length: 23091, dtype: float64

# %%
taxi1.head()
# Out:
#                          journey_id                           user_id  \
# 0  23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 1  dd2af4715d0dc16eded53afc0e243577  a553c46e3a22fb9c326aeb3d72b3334e
# 2  dd91e131888064bf7df3ce08f3d4b4ad  a553c46e3a22fb9c326aeb3d72b3334e
# 3  dd2af4715d0dc16eded53afc0e2466d0  a553c46e3a22fb9c326aeb3d72b3334e
# 4  85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
#
#                           driver_id                           taxi_id  \
# 0  583949a89a9ee17d19e3ca4f137b6b4c  b12f4f09c783e29fe0d0ea624530db56
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4  d665fb9f75ef5d9cd0fd89479380ba78  0accdd3aa5a322f4129fa20b53278c69
#
#         icon start_type            start_at     start_lat     start_lon  \
# ...

# %%
taxi
# Out:
#                              journey_id                           user_id  \
# 0      23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 1      dd2af4715d0dc16eded53afc0e243577  a553c46e3a22fb9c326aeb3d72b3334e
# 2      dd91e131888064bf7df3ce08f3d4b4ad  a553c46e3a22fb9c326aeb3d72b3334e
# 3      dd2af4715d0dc16eded53afc0e2466d0  a553c46e3a22fb9c326aeb3d72b3334e
# 4      85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
# ...                                 ...                               ...
# 23106  4a18ea5737ce0ffecaf20b305a0e2c86  8998bb370b5f0cec43a373adebba0c72
# 23107  f1e4317f2c17991dd90d1cd17ae0d399  5f8a6ffef0ea5df78a8ee890267b60ec
# 23108  1e44c0fd0a266c3719ff30410b257bce  c0ffb6f6cd801004dd8609c12277c2d1
# 23109  7073883383b89ad289e864022150cdd7  c0ffb6f6cd801004dd8609c12277c2d1
# 23110  b7dea45c3cc92b9efd5a4905e69ff9bf  c0ffb6f6cd801004dd8609c12277c2d1
#
#                               driver_id                           taxi_id  \
# ...

# %%
# я хз че наверху происходило, там пайтон не разрешал сделать по-другому, пришлось вводить taxi1

# %%
taxi.query('start_type == "reserved" and wait_time > 0.0').groupby('driver_id').agg(count_miss=('driver_id', 'count')).sort_values('count_miss', ascending = True)
# Out:
#                                   count_miss
# driver_id
# d7bf644eb441cda6127f91addebb85c4           1
# b68895736389f2949faa8c73555b81ac           1
# b5821eaaa5d49fb2936ff5b0ffa34a35           1
# b44159c128d31f55629260b671ab83ac           1
# 9db6243faff23197787d1efc5f93904d           1
# ...                                      ...
# c814db2127582cf95dea1f74f43127c2          45
# 56f59b58bcbbd1cdabc3652e713134c2          51
# ec84a73745199ff840ecafcb924383ad          57
# d665fb9f75ef5d9cd0fd89479380ba78          59
# 406921adcca37705ef527b4246c0cfea          67
#
# [105 rows x 1 columns]

# %%
taxi.query('driver_id == "406921adcca37705ef527b4246c0cfea" and start_type == "reserved" and wait_time > 0.0')
# Out:
#                              journey_id                           user_id  \
# 67     eb06449983dd990ff162c0ad990909ba  933a5cf7834b12121755b8586b53a083
# 197    275052e660ff5672db6624c42b6b4f59  29a360323f1754d8cf08023eb1f3dbb7
# 434    c32c353f4a9bc8ae2e079e6bb7cb9366  0280ac72b104d8a55d2d23d5321b665f
# 1055   bb3af86cd1cc8948a514796d363f9dce  0a98cead98f3935ef3051e834a30419e
# 1067   6f2fdf6e4148cb011614ac61629d2c6d  8e37a68fab5f31a5e2c1b5f77c6bb9e5
# ...                                 ...                               ...
# 21522  1881c928349fa432c4c0cb4434802c81  16cbe35db7fff70fbc8251b4cdc843b1
# 21661  2254715f0f569e3173ec61f16cdcc1e6  86aa09456b63a2a25e0097c5520497ec
# 21890  2f1882c87731970df63e69d4bc2515da  68fe4d0ad82cc2d715d131953336d717
# 22378  5111ac6114962976d7fd625788b072ca  0a98cead98f3935ef3051e834a30419e
# 22654  5ecedc9ef1c775232764e9f7b01430c4  fd3831b43f038c9ee0e840c18bc56ea0
#
#                               driver_id                           taxi_id  \
# ...

# %%
taxi['month'] = taxi['start_at'].dt.month.astype(int)

# %%
taxi['weekday'] = taxi['start_at'].dt.strftime('%A')

# %%
taxi
# Out:
#                              journey_id                           user_id  \
# 0      23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 1      dd2af4715d0dc16eded53afc0e243577  a553c46e3a22fb9c326aeb3d72b3334e
# 2      dd91e131888064bf7df3ce08f3d4b4ad  a553c46e3a22fb9c326aeb3d72b3334e
# 3      dd2af4715d0dc16eded53afc0e2466d0  a553c46e3a22fb9c326aeb3d72b3334e
# 4      85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
# ...                                 ...                               ...
# 23106  4a18ea5737ce0ffecaf20b305a0e2c86  8998bb370b5f0cec43a373adebba0c72
# 23107  f1e4317f2c17991dd90d1cd17ae0d399  5f8a6ffef0ea5df78a8ee890267b60ec
# 23108  1e44c0fd0a266c3719ff30410b257bce  c0ffb6f6cd801004dd8609c12277c2d1
# 23109  7073883383b89ad289e864022150cdd7  c0ffb6f6cd801004dd8609c12277c2d1
# 23110  b7dea45c3cc92b9efd5a4905e69ff9bf  c0ffb6f6cd801004dd8609c12277c2d1
#
#                               driver_id                           taxi_id  \
# ...

# %%
taxi.dtypes
# Out:
# journey_id                  object
# user_id                     object
# driver_id                   object
# taxi_id                     object
# icon                        object
# start_type                  object
# start_at            datetime64[ns]
# start_lat                   object
# start_lon                   object
# end_at              datetime64[ns]
# end_lat                     object
# end_lon                     object
# end_state                   object
# driver_start_lat            object
# driver_start_lon            object
# arrived_at          datetime64[ns]
# source                      object
# driver_score               float64
# rider_score                float64
# wait_time                  float64
# month                        int64
# weekday                     object
# dtype: object

# %%
sns.displot(taxi.month)

# %%
sns.countplot(taxi['weekday'], order=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
k = taxi.groupby('month', as_index = False).agg(unique_users=('user_id','nunique'))

# %%
taxi.groupby('month', as_index = False).agg(unique_users=('user_id','nunique'))
# Out:
#     month  unique_users
# 0       1           102
# 1       2           110
# 2       3           162
# 3       4           253
# 4       5           275
# 5       6           309
# 6       7           318
# 7       8           377
# 8       9           416
# 9      10           437
# 10     11           504
# 11     12           569

# %%
sns.lineplot(k.month, k.unique_users)
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
